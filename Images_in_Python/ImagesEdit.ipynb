# %% [markdown]
# # 🖼️ Working with Images in Python (Pillow Library)
#
# This notebook demonstrates how to open, inspect, manipulate, and modify images using the **Pillow (PIL)** library in Python.
#
# ---
#
# ## 🧩 Import and Open an Image

# %%
from PIL import Image
from IPython.display import display

# Open the image
img = Image.open("spring_trees.jpg")

# Show basic information
print("📏 Size:", img.size)
print("📄 Format:", img.format)
print("🎨 Mode:", img.mode)

# Display the image
display(img)
# Out:
# 📏 Size: (900, 600)
# 📄 Format: JPEG
# 🎨 Mode: RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x600>
